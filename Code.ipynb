# %%
from backend2 import World
import numpy as np

# %%
world = World(137)
world.add_country("gb", "Data/gb.csv", 66_650_000, 0.000027)
world.add_country("fr", "Data/fr.csv", 66_990_000, 0.000029)
world.add_country("it", "Data/it.csv", 60_360_000, 0.000020)
world.add_country("sp", "Data/sp.csv", 46_940_000, 0.000022)
world.add_country("ge", "Data/ge.csv", 83_020_000, 0.000026)
world.add_country("row", "Data/row.csv", 7_465_790_000, 0.000046) # rest of the world

world.country_list_complete()

# %%
world.add_migration("gb", "fr", "Data/gb-fr.csv")
world.add_migration("gb", "it", "Data/gb-it.csv")
world.add_migration("gb", "sp", "Data/gb-sp.csv")
world.add_migration("gb", "ge", "Data/gb-ge.csv")
world.add_migration("gb", "row", "Data/gb-row.csv")

world.add_migration("fr", "it", "Data/fr-it.csv")
world.add_migration("fr", "sp", "Data/fr-sp.csv")
world.add_migration("fr", "ge", "Data/fr-ge.csv")
world.add_migration("fr", "row", "Data/fr-row.csv")

world.add_migration("it", "sp", "Data/it-sp.csv")
world.add_migration("it", "ge", "Data/it-ge.csv")
world.add_migration("it", "row", "Data/it-row.csv")

world.add_migration("sp", "ge", "Data/sp-ge.csv")
world.add_migration("sp", "row", "Data/sp-row.csv")

world.add_migration("ge", "row", "Data/ge-row.csv")

# %%
params = world.fit(0, len(world.countries_data), np.append(np.concatenate([[world.N[i], 0, 0, 0, 0] for i in range(world.num_countries - 1)]), [world.N[-1], 0, 1, 0, 0]))

result = world.odesolve(np.concatenate([[world.N[i], 0, 0, 0, 0] for i in range(world.num_countries - 1)]) + [world.N[-1], 0, 1, 0, 0], range(world.time), params)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-1b1838c7e9a4> in <module>
# ----> 1 params = world.fit(0, len(world.countries_data), np.append(np.concatenate([[world.N[i], 0, 0, 0, 0] for i in range(world.num_countries - 1)]), [world.N[-1], 0, 1, 0, 0]))
#       2
#       3 result = world.odesolve(np.concatenate([[world.N[i], 0, 0, 0, 0] for i in range(world.num_countries - 1)]) + [world.N[-1], 0, 1, 0, 0], range(world.time), params)
#
# ~\Documents\Summer Project\backend2.py in fit(self, start, end, y0)
#      77         x0 = np.array([np.ones(self.num_countries)]*4).flatten()
#      78         bounds = np.array([(0, np.inf)]*self.num_countries*4)
# ---> 79         return optimize.minimize(self.__cost(start, end, y0), x0=x0, method="L-BFGS-B", bounds=bounds)
#      80
#      81 world = World(137)
#
# ...
